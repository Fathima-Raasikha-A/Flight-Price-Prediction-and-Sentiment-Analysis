# %% [markdown]
# # Passenger Satisfaction-CLASSIFICATION

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\razih\Downloads\Passenger_Satisfaction.csv")
df
# Out:
#         Unnamed: 0      id  ... Arrival Delay in Minutes             satisfaction
# 0                0   70172  ...                     18.0  neutral or dissatisfied
# 1                1    5047  ...                      6.0  neutral or dissatisfied
# 2                2  110028  ...                      0.0                satisfied
# 3                3   24026  ...                      9.0  neutral or dissatisfied
# 4                4  119299  ...                      0.0                satisfied
# ...            ...     ...  ...                      ...                      ...
# 103899      103899   94171  ...                      0.0  neutral or dissatisfied
# 103900      103900   73097  ...                      0.0                satisfied
# 103901      103901   68825  ...                     14.0  neutral or dissatisfied
# 103902      103902   54173  ...                      0.0  neutral or dissatisfied
# 103903      103903   62567  ...                      0.0  neutral or dissatisfied
#
# [103904 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# dtype: int64

# %%
df=df.dropna()
df.head(2)
# Out:
#    Unnamed: 0     id  ... Arrival Delay in Minutes             satisfaction
# 0           0  70172  ...                     18.0  neutral or dissatisfied
# 1           1   5047  ...                      6.0  neutral or dissatisfied
#
# [2 rows x 25 columns]

# %%
df=df.drop(["Unnamed: 0","id"],axis=1)
df.head(2)
# Out:
#   Gender      Customer Type  ...  Arrival Delay in Minutes             satisfaction
# 0   Male     Loyal Customer  ...                      18.0  neutral or dissatisfied
# 1   Male  disloyal Customer  ...                       6.0  neutral or dissatisfied
#
# [2 rows x 23 columns]

# %%
df['satisfaction'].value_counts(normalize=True)
# Out:
# satisfaction
# neutral or dissatisfied    0.566606
# satisfied                  0.433394
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(df["satisfaction"])
plt.show()

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   Gender      Customer Type  ...  Arrival Delay in Minutes             satisfaction
# 0   Male     Loyal Customer  ...                      18.0  neutral or dissatisfied
# 1   Male  disloyal Customer  ...                       6.0  neutral or dissatisfied
#
# [2 rows x 23 columns]

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

cat_columns = ["Gender","Customer Type","Type of Travel","Class","satisfaction"]
for col in cat_columns:
     label= LabelEncoder()
     df[col] = label.fit_transform(df[col])
df.head(2)
# Out:
#    Gender  Customer Type  ...  Arrival Delay in Minutes  satisfaction
# 0       1              0  ...                      18.0             0
# 1       1              1  ...                       6.0             0
#
# [2 rows x 23 columns]

# %%
df
# Out:
#         Gender  Customer Type  ...  Arrival Delay in Minutes  satisfaction
# 0            1              0  ...                      18.0             0
# 1            1              1  ...                       6.0             0
# 2            0              0  ...                       0.0             1
# 3            0              0  ...                       9.0             0
# 4            1              0  ...                       0.0             1
# ...        ...            ...  ...                       ...           ...
# 103899       0              1  ...                       0.0             0
# 103900       1              0  ...                       0.0             1
# 103901       1              1  ...                      14.0             0
# 103902       0              1  ...                       0.0             0
# 103903       1              0  ...                       0.0             0
#
# [103594 rows x 23 columns]

# %%
import pandas as pd
import mlflow
import mlflow.sklearn
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report,accuracy_score, precision_score, recall_score, f1_score

# %%
# Define features and target variable
X = df.drop(['satisfaction'], axis=1)
y = df['satisfaction']

# Handle class imbalance using SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Split dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)
models = [
    LogisticRegression(max_iter=1000),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    GradientBoostingClassifier(),
    AdaBoostClassifier()
]
mlflow.set_experiment("Customer_Satisfaction_Classification")
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# Training and evaluating classifiers with MLflow tracking
for model in models:
    with mlflow.start_run(run_name = type(model).__name__):
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        
        acc = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, average='weighted')
        recall = recall_score(y_test, y_pred, average='weighted')
        f1 = f1_score(y_test, y_pred, average='weighted')
        #class_report = classification_report(y_test, y_pred)

        mlflow.log_param("model_name", type(model).__name__)
        mlflow.log_metric("accuracy", acc)
        mlflow.log_metric("precision", precision)
        mlflow.log_metric("recall", recall)
        mlflow.log_metric("f1_score", f1)
        
        mlflow.sklearn.log_model(model, type(model).__name__)
        
        print(f"{type(model).__name__} Results:")
        print(f"Accuracy: {acc}")
        print(f"Precision: {precision}")
        print(f"Recall: {recall}")
        print(f"F1 Score: {f1}\n")
# Out:
# c:\Users\razih\OneDrive\Desktop\New\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 2025/02/24 14:03:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# LogisticRegression Results:
# Accuracy: 0.8703096384002725
# Precision: 0.8703173769829797
# Recall: 0.8703096384002725
# F1 Score: 0.8703108537896015
#
# 🏃 View run LogisticRegression at: http://127.0.0.1:5000/#/experiments/221267984704764691/runs/570dca7a9db64436b2914c21ff461e9f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/221267984704764691
# 2025/02/24 14:03:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# DecisionTreeClassifier Results:
# Accuracy: 0.9411388900719793
# Precision: 0.9411570710495373
# Recall: 0.9411388900719793
# F1 Score: 0.941139615086062
#
# 🏃 View run DecisionTreeClassifier at: http://127.0.0.1:5000/#/experiments/221267984704764691/runs/db53a14a80ec46b5a04615247acde963
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/221267984704764691
# 2025/02/24 14:03:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# RandomForestClassifier Results:
# Accuracy: 0.9600068146002811
# Precision: 0.9601645889480422
# Recall: 0.9600068146002811
# F1 Score: 0.9600005920355755
#
# 🏃 View run RandomForestClassifier at: http://127.0.0.1:5000/#/experiments/221267984704764691/runs/d55dac76b03740e5ac75c5f33bd0e4c7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/221267984704764691
# 2025/02/24 14:04:12 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# GradientBoostingClassifier Results:
# Accuracy: 0.9365390348822352
# Precision: 0.9365815028795111
# Recall: 0.9365390348822352
# F1 Score: 0.9365349753970708
#
# 🏃 View run GradientBoostingClassifier at: http://127.0.0.1:5000/#/experiments/221267984704764691/runs/4aca4d085af94a9c93299c7cd5b07e3e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/221267984704764691
# 2025/02/24 14:04:21 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# AdaBoostClassifier Results:
# Accuracy: 0.9093232250095831
# Precision: 0.9093233810984526
# Recall: 0.9093232250095831
# F1 Score: 0.9093225755653518
#
# 🏃 View run AdaBoostClassifier at: http://127.0.0.1:5000/#/experiments/221267984704764691/runs/8ef9e276b0e64b1fa9556c8836c9362c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/221267984704764691
